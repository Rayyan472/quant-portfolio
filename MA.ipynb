# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

ticker = "MSFT"
data = yf.download(ticker, start="2023-01-01", end="2025-01-01")
data["MA20"] = data["Close"].rolling(window=20).mean()
data["MA50"] = data["Close"].rolling(window=50).mean()

plt.figure(figsize = (12,6))
plt.plot(data["Close"], label = "Close Price", color = "blue")
plt.plot(data["MA20"], label = "20-Day MA", color = "orange")
plt.plot(data["MA50"], label = "50-Day MA", color = "red")
plt.title(f"{ticker} Price with 20 & 50 Day Moving Averages")
plt.legend()
plt.show()
# Out:
# C:\Users\rayya\AppData\Local\Temp\ipykernel_16596\4058879650.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2023-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
